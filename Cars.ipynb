# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
df = pd.read_csv("car-sales.csv")

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(df.Make, df.Doors)
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales = df[["Make", "Odometer (KM)"]]

# %%
car_sales
# Out:
#      Make  Odometer (KM)
# 0  Toyota         150043
# 1   Honda          87899
# 2  Toyota          32549
# 3     BMW          11179
# 4  Nissan         213095
# 5  Toyota          99213
# 6   Honda          45698
# 7   Honda          54738
# 8  Toyota          60000
# 9  Nissan          31600

# %%
car_sales.groupby("Make").mean()
# Out:
#         Odometer (KM)
# Make
# BMW      11179.000000
# Honda    62778.333333
# Nissan  122347.500000
# Toyota   85451.250000

# %%
df["Price"] = df["Price"].str.replace('[\$\,]|\.\d*', '', regex=True).astype(int)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
cars_missing_drop = df.dropna()

# %%
cars_missing_drop
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
series_doors = pd.Series([5,5,5,5,5])

# %%
df["Seats"] = series_doors

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4   4000    5.0
# 1   Honda    Red          87899      4   5000    5.0
# 2  Toyota   Blue          32549      3   7000    5.0
# 3     BMW  Black          11179      5  22000    5.0
# 4  Nissan  White         213095      4   3500    5.0
# 5  Toyota  Green          99213      4   4500    NaN
# 6   Honda   Blue          45698      4   7500    NaN
# 7   Honda   Blue          54738      4   7000    NaN
# 8  Toyota  White          60000      4   6250    NaN
# 9  Nissan  White          31600      4   9700    NaN

# %%
df.fillna(5, inplace = True)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4   4000    5.0
# 1   Honda    Red          87899      4   5000    5.0
# 2  Toyota   Blue          32549      3   7000    5.0
# 3     BMW  Black          11179      5  22000    5.0
# 4  Nissan  White         213095      4   3500    5.0
# 5  Toyota  Green          99213      4   4500    5.0
# 6   Honda   Blue          45698      4   7500    5.0
# 7   Honda   Blue          54738      4   7000    5.0
# 8  Toyota  White          60000      4   6250    5.0
# 9  Nissan  White          31600      4   9700    5.0

# %%
fuel_used = [3.4, 5.8, 7.9, 4.9, 8.2, 5.4, 5.8, 9.4, 7.5, 3.23]
df["Fuel used per 100 (Km)"] = fuel_used

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel used per 100 (Km)
# 0  Toyota  White         150043      4   4000    5.0                    3.40
# 1   Honda    Red          87899      4   5000    5.0                    5.80
# 2  Toyota   Blue          32549      3   7000    5.0                    7.90
# 3     BMW  Black          11179      5  22000    5.0                    4.90
# 4  Nissan  White         213095      4   3500    5.0                    8.20
# 5  Toyota  Green          99213      4   4500    5.0                    5.40
# 6   Honda   Blue          45698      4   7500    5.0                    5.80
# 7   Honda   Blue          54738      4   7000    5.0                    9.40
# 8  Toyota  White          60000      4   6250    5.0                    7.50
# 9  Nissan  White          31600      4   9700    5.0                    3.23

# %%
df["Total Fuel Used"] = df["Odometer (KM)"] / 100 * df["Fuel used per 100 (Km)"]

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel used per 100 (Km)  \
# 0  Toyota  White         150043      4   4000    5.0                    3.40
# 1   Honda    Red          87899      4   5000    5.0                    5.80
# 2  Toyota   Blue          32549      3   7000    5.0                    7.90
# 3     BMW  Black          11179      5  22000    5.0                    4.90
# 4  Nissan  White         213095      4   3500    5.0                    8.20
# 5  Toyota  Green          99213      4   4500    5.0                    5.40
# 6   Honda   Blue          45698      4   7500    5.0                    5.80
# 7   Honda   Blue          54738      4   7000    5.0                    9.40
# 8  Toyota  White          60000      4   6250    5.0                    7.50
# 9  Nissan  White          31600      4   9700    5.0                    3.23
#
#    Total Fuel Used
# 0         5101.462
# 1         5098.142
# 2         2571.371
# 3          547.771
# 4        17473.790
# ...

# %%
df["Wheels"] = 4

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel used per 100 (Km)  \
# 0  Toyota  White         150043      4   4000    5.0                    3.40
# 1   Honda    Red          87899      4   5000    5.0                    5.80
# 2  Toyota   Blue          32549      3   7000    5.0                    7.90
# 3     BMW  Black          11179      5  22000    5.0                    4.90
# 4  Nissan  White         213095      4   3500    5.0                    8.20
# 5  Toyota  Green          99213      4   4500    5.0                    5.40
# 6   Honda   Blue          45698      4   7500    5.0                    5.80
# 7   Honda   Blue          54738      4   7000    5.0                    9.40
# 8  Toyota  White          60000      4   6250    5.0                    7.50
# 9  Nissan  White          31600      4   9700    5.0                    3.23
#
#    Total Fuel Used  Wheels
# 0         5101.462       4
# 1         5098.142       4
# 2         2571.371       4
# ...

# %%
df = df.drop("Total Fuel Used", axis = 1)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel used per 100 (Km)  \
# 0  Toyota  White         150043      4   4000    5.0                    3.40
# 1   Honda    Red          87899      4   5000    5.0                    5.80
# 2  Toyota   Blue          32549      3   7000    5.0                    7.90
# 3     BMW  Black          11179      5  22000    5.0                    4.90
# 4  Nissan  White         213095      4   3500    5.0                    8.20
# 5  Toyota  Green          99213      4   4500    5.0                    5.40
# 6   Honda   Blue          45698      4   7500    5.0                    5.80
# 7   Honda   Blue          54738      4   7000    5.0                    9.40
# 8  Toyota  White          60000      4   6250    5.0                    7.50
# 9  Nissan  White          31600      4   9700    5.0                    3.23
#
#    Wheels
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# 5       4
# 6       4
# 7       4
# 8       4
# ...

# %%
df["Odometer (KM)"] = df["Odometer (KM)"].apply(lambda x : x /1.6)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel used per 100 (Km)  \
# 0  Toyota  White      93776.875      4   4000    5.0                    3.40
# 1   Honda    Red      54936.875      4   5000    5.0                    5.80
# 2  Toyota   Blue      20343.125      3   7000    5.0                    7.90
# 3     BMW  Black       6986.875      5  22000    5.0                    4.90
# 4  Nissan  White     133184.375      4   3500    5.0                    8.20
# 5  Toyota  Green      62008.125      4   4500    5.0                    5.40
# 6   Honda   Blue      28561.250      4   7500    5.0                    5.80
# 7   Honda   Blue      34211.250      4   7000    5.0                    9.40
# 8  Toyota  White      37500.000      4   6250    5.0                    7.50
# 9  Nissan  White      19750.000      4   9700    5.0                    3.23
#
#    Wheels
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
# 5       4
# 6       4
# 7       4
# 8       4
# ...

# %%
df.rename(columns = {'Odometer (KM)':'Odometer (Mile)'}, inplace = True)

# %%
df
# Out:
#      Make Colour  Odometer (Mile)  Doors  Price  Seats  \
# 0  Toyota  White        93776.875      4   4000    5.0
# 1   Honda    Red        54936.875      4   5000    5.0
# 2  Toyota   Blue        20343.125      3   7000    5.0
# 3     BMW  Black         6986.875      5  22000    5.0
# 4  Nissan  White       133184.375      4   3500    5.0
# 5  Toyota  Green        62008.125      4   4500    5.0
# 6   Honda   Blue        28561.250      4   7500    5.0
# 7   Honda   Blue        34211.250      4   7000    5.0
# 8  Toyota  White        37500.000      4   6250    5.0
# 9  Nissan  White        19750.000      4   9700    5.0
#
#    Fuel used per 100 (Km)  Wheels
# 0                    3.40       4
# 1                    5.80       4
# 2                    7.90       4
# 3                    4.90       4
# 4                    8.20       4
# 5                    5.40       4
# 6                    5.80       4
# 7                    9.40       4
# 8                    7.50       4
# ...

# %% [markdown]
# # Numpy Play around

# %%
import numpy as np

# %%
a = np.array([1,2,3])
a
# Out:
# array([1, 2, 3])

# %%
b = np.array([(1.5,2,3), (4,5,6)], dtype = float)
c = np.array([[(1.5,2,3), (4,5,6)],[(3,2,1), (4,5,6)]], dtype = float)

# %%
b
# Out:
# array([[1.5, 2. , 3. ],
#        [4. , 5. , 6. ]])

# %%
c
# Out:
# array([[[1.5, 2. , 3. ],
#         [4. , 5. , 6. ]],
#
#        [[3. , 2. , 1. ],
#         [4. , 5. , 6. ]]])

# %%
c[1][1][2]
# Out:
# 6.0

# %%
a4 =  np.random.randint(10 , size= (2,3,4,5))

# %%
a4
# Out:
# array([[[[0, 8, 2, 7, 3],
#          [9, 8, 7, 1, 5],
#          [1, 9, 1, 9, 5],
#          [2, 4, 5, 8, 6]],
#
#         [[6, 2, 5, 4, 8],
#          [4, 8, 2, 4, 9],
#          [3, 2, 5, 2, 9],
#          [4, 6, 1, 2, 6]],
#
#         [[6, 8, 1, 1, 3],
#          [7, 3, 8, 8, 7],
#          [7, 4, 0, 8, 2],
#          [7, 0, 6, 2, 3]]],
#
#
#        [[[3, 4, 5, 6, 1],
#          [9, 5, 9, 3, 6],
#          [6, 7, 3, 5, 8],
#          [5, 9, 5, 8, 8]],
#
#         [[7, 2, 3, 2, 9],
#          [8, 2, 1, 5, 7],
#          [8, 0, 0, 3, 6],
#          [1, 6, 8, 1, 8]],
#
#         [[0, 7, 3, 7, 8],
#          [0, 0, 3, 8, 9],
#          [7, 7, 8, 0, 5],
#          [0, 9, 8, 9, 9]]]])

# %%
a4.shape
# Out:
# (2, 3, 4, 5)

# %%
a4[1][1][0]
# Out:
# array([7, 2, 3, 2, 9])

# %%
b.shape
# Out:
# (2, 3)

# %%
a
# Out:
# array([1, 2, 3])

# %%
a_multiply_b = a *b

# %%
a_multiply_b
# Out:
# array([[ 1.5,  4. ,  9. ],
#        [ 4. , 10. , 18. ]])

# %%
a_3_2 =  np.random.randint(10 , size= (3,2))
a_3_2
# Out:
# array([[5, 2],
#        [1, 3],
#        [0, 3]])

# %%
# Define a matrix with 2 rows and 3 columns
matrix_a = np.array([[1, 2, 3],
                    [4, 5, 6]])

# Define a matrix with 3 rows and 2 columns
matrix_b = np.array([[7, 8],
                    [9, 10],
                    [11, 12]])

# Perform matrix multiplication
result_matrix = np.dot(matrix_a, matrix_b)

# Alternatively, you can use the @ operator for matrix multiplication in Python 3.5 and above
# result_matrix = matrix_a @ matrix_b

print("Matrix A:")
print(matrix_a)
print("\nMatrix B:")
print(matrix_b)
print("\nResult of Matrix Multiplication:")
print(result_matrix)
# Out:
# Matrix A:
# [[1 2 3]
#  [4 5 6]]
#
# Matrix B:
# [[ 7  8]
#  [ 9 10]
#  [11 12]]
#
# Result of Matrix Multiplication:
# [[ 58  64]
#  [139 154]]

# %%
a_3_4 =  np.random.randint(10 , size= (3,4))
a_3_4
# Out:
# array([[0, 6, 5, 5],
#        [8, 6, 7, 4],
#        [6, 4, 8, 1]])

# %%
a_2_2 =  np.random.randint(10 , size= (2,2))
a_2_2
# Out:
# array([[5, 5],
#        [5, 1]])

# %%
result = np.dot(a_3_4, a_2_2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 result = np.dot(a_3_4, a_2_2)
#
# ValueError: shapes (3,4) and (2,2) not aligned: 4 (dim 1) != 2 (dim 0)

# %%
a_3_4.ndim
# Out:
# 2

# %%
a_2_2.ndim
# Out:
# 2

# %%
a_3_4.dot(a_2_2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 a_3_4.dot(a_2_2)
#
# ValueError: shapes (3,4) and (2,2) not aligned: 4 (dim 1) != 2 (dim 0)

# %%
a_3_4
# Out:
# array([[0, 6, 5, 5],
#        [8, 6, 7, 4],
#        [6, 4, 8, 1]])

# %%
a_2_2
# Out:
# array([[5, 5],
#        [5, 1]])
